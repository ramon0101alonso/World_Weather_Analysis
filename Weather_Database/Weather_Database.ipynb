# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
# Copy from WeatherPy

lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 622

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
#dont forget to delete url because it has the api address
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_weather = requests.get(city_url).json()      
            
        # Append the city information into the city_data list
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # read the list to a temp and then read the actual description
        city_weatherdesc = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weatherdesc
                          })
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | ushuaia
# Processing Record 2 of Set 1 | tuktoyaktuk
# Processing Record 3 of Set 1 | hermanus
# Processing Record 4 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 5 of Set 1 | tessalit
# Processing Record 6 of Set 1 | kavaratti
# Processing Record 7 of Set 1 | olafsvik
# Processing Record 8 of Set 1 | chokurdakh
# Processing Record 9 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 10 of Set 1 | busselton
# Processing Record 11 of Set 1 | toliary
# City not found. Skipping...
# Processing Record 12 of Set 1 | saskylakh
# Processing Record 13 of Set 1 | ponta do sol
# Processing Record 14 of Set 1 | tabuny
# Processing Record 15 of Set 1 | kahului
# Processing Record 16 of Set 1 | yulara
# Processing Record 17 of Set 1 | jamestown
# Processing Record 18 of Set 1 | baft
# Processing Record 19 of Set 1 | son la
# Processing Record 20 of Set 1 | hobart
# Processing Record 21 of Set 1 | seinajoki
# Processing Record 22 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 23 of Set 1 | avarua
# Processing Record 24 of Set 1 | butaritari
# Processing Record 25 of Set 1 | cayenne
# Processing Record 26 of Set 1 | bredasdorp
# Processing Record 27 of Set 1 | cape town
# Processing Record 28 of Set 1 | fuerte olimpo
# Processing Record 29 of Set 1 | port alfred
# Processing Record 30 of Set 1 | rikitea
# Processing Record 31 of Set 1 | burnie
# Processing Record 32 of Set 1 | orbetello
# Processing Record 33 of Set 1 | upernavik
# Processing Record 34 of Set 1 | poum
# Processing Record 35 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 36 of Set 1 | albany
# Processing Record 37 of Set 1 | new norfolk
# Processing Record 38 of Set 1 | asau
# Processing Record 39 of Set 1 | aklavik
# Processing Record 40 of Set 1 | vila velha
# Processing Record 41 of Set 1 | tawkar
# City not found. Skipping...
# Processing Record 42 of Set 1 | ribeira grande
# Processing Record 43 of Set 1 | chilca
# Processing Record 44 of Set 1 | mataura
# Processing Record 45 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 46 of Set 1 | vaini
# Processing Record 47 of Set 1 | barrow
# Processing Record 48 of Set 1 | cabo san lucas
# Processing Record 49 of Set 1 | port hedland
# Processing Record 50 of Set 1 | lagoa
# Processing Record 1 of Set 2 | punta arenas
# Processing Record 2 of Set 2 | lunino
# Processing Record 3 of Set 2 | bairiki
# Processing Record 4 of Set 2 | plettenberg bay
# Processing Record 5 of Set 2 | kapaa
# Processing Record 6 of Set 2 | ostrovnoy
# Processing Record 7 of Set 2 | ancud
# Processing Record 8 of Set 2 | torbay
# Processing Record 9 of Set 2 | westport
# Processing Record 10 of Set 2 | dzerzhinsk
# Processing Record 11 of Set 2 | lompoc
# Processing Record 12 of Set 2 | oakdale
# Processing Record 13 of Set 2 | saint george
# Processing Record 14 of Set 2 | west wendover
# Processing Record 15 of Set 2 | mainit
# Processing Record 16 of Set 2 | bluff
# Processing Record 17 of Set 2 | victoria
# Processing Record 18 of Set 2 | bowen
# Processing Record 19 of Set 2 | chak jhumra
# Processing Record 20 of Set 2 | nacozari
# Processing Record 21 of Set 2 | arraial do cabo
# Processing Record 22 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 23 of Set 2 | yellowknife
# Processing Record 24 of Set 2 | comodoro rivadavia
# Processing Record 25 of Set 2 | namatanai
# Processing Record 26 of Set 2 | constitucion
# Processing Record 27 of Set 2 | massaguet
# Processing Record 28 of Set 2 | bol
# Processing Record 29 of Set 2 | carnarvon
# Processing Record 30 of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 31 of Set 2 | samalaeulu
# City not found. Skipping...
# Processing Record 32 of Set 2 | dubbo
# Processing Record 33 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 34 of Set 2 | port elizabeth
# Processing Record 35 of Set 2 | shelburne
# Processing Record 36 of Set 2 | tsumeb
# Processing Record 37 of Set 2 | husavik
# Processing Record 38 of Set 2 | kaitangata
# Processing Record 39 of Set 2 | dikson
# Processing Record 40 of Set 2 | qaanaaq
# Processing Record 41 of Set 2 | moron
# Processing Record 42 of Set 2 | tasiilaq
# Processing Record 43 of Set 2 | sao joao da ponte
# Processing Record 44 of Set 2 | nikolskoye
# Processing Record 45 of Set 2 | pevek
# Processing Record 46 of Set 2 | northam
# Processing Record 47 of Set 2 | abu samrah
# Processing Record 48 of Set 2 | hithadhoo
# Processing Record 49 of Set 2 | acarau
# Processing Record 50 of Set 2 | kirakira
# Processing Record 1 of Set 3 | sao jose da coroa grande
# Processing Record 2 of Set 3 | kruisfontein
# Processing Record 3 of Set 3 | chagda
# City not found. Skipping...
# Processing Record 4 of Set 3 | saldanha
# Processing Record 5 of Set 3 | castro
# Processing Record 6 of Set 3 | east london
# Processing Record 7 of Set 3 | zyryanka
# Processing Record 8 of Set 3 | jingdezhen
# Processing Record 9 of Set 3 | banda aceh
# Processing Record 10 of Set 3 | nara
# Processing Record 11 of Set 3 | dudinka
# Processing Record 12 of Set 3 | darhan
# Processing Record 13 of Set 3 | port lincoln
# Processing Record 14 of Set 3 | narsaq
# Processing Record 15 of Set 3 | los llanos de aridane
# Processing Record 16 of Set 3 | verkhoyansk
# Processing Record 17 of Set 3 | katsuura
# Processing Record 18 of Set 3 | namibe
# Processing Record 19 of Set 3 | zhangjiakou
# Processing Record 20 of Set 3 | kwinana
# Processing Record 21 of Set 3 | bogota
# Processing Record 22 of Set 3 | chicama
# Processing Record 23 of Set 3 | cangas
# Processing Record 24 of Set 3 | tahta
# Processing Record 25 of Set 3 | ghioroc
# Processing Record 26 of Set 3 | norman wells
# Processing Record 27 of Set 3 | half moon bay
# Processing Record 28 of Set 3 | lebu
# Processing Record 29 of Set 3 | tuatapere
# Processing Record 30 of Set 3 | kosya
# City not found. Skipping...
# Processing Record 31 of Set 3 | raudeberg
# Processing Record 32 of Set 3 | mar del plata
# Processing Record 33 of Set 3 | gat
# Processing Record 34 of Set 3 | altay
# Processing Record 35 of Set 3 | zhigansk
# Processing Record 36 of Set 3 | kodiak
# Processing Record 37 of Set 3 | tautira
# Processing Record 38 of Set 3 | coihaique
# Processing Record 39 of Set 3 | ahipara
# Processing Record 40 of Set 3 | suraabad
# Processing Record 41 of Set 3 | puerto ayora
# Processing Record 42 of Set 3 | dakar
# Processing Record 43 of Set 3 | pangkalanbuun
# Processing Record 44 of Set 3 | emba
# Processing Record 45 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 46 of Set 3 | hay river
# Processing Record 47 of Set 3 | la ronge
# Processing Record 48 of Set 3 | irituia
# Processing Record 49 of Set 3 | coquimbo
# Processing Record 50 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 1 of Set 4 | solovetskiy
# City not found. Skipping...
# Processing Record 2 of Set 4 | zaoyang
# Processing Record 3 of Set 4 | ures
# Processing Record 4 of Set 4 | kondinskoye
# Processing Record 5 of Set 4 | lalmohan
# Processing Record 6 of Set 4 | puerto escondido
# Processing Record 7 of Set 4 | luba
# Processing Record 8 of Set 4 | iqaluit
# Processing Record 9 of Set 4 | severo-kurilsk
# Processing Record 10 of Set 4 | atuona
# Processing Record 11 of Set 4 | dingle
# Processing Record 12 of Set 4 | baruun-urt
# Processing Record 13 of Set 4 | tarudant
# City not found. Skipping...
# Processing Record 14 of Set 4 | thompson
# Processing Record 15 of Set 4 | hami
# Processing Record 16 of Set 4 | evensk
# Processing Record 17 of Set 4 | clyde river
# Processing Record 18 of Set 4 | eureka
# Processing Record 19 of Set 4 | bambous virieux
# Processing Record 20 of Set 4 | georgetown
# Processing Record 21 of Set 4 | naryan-mar
# Processing Record 22 of Set 4 | nanortalik
# Processing Record 23 of Set 4 | murgab
# Processing Record 24 of Set 4 | liuzhou
# Processing Record 25 of Set 4 | sile
# Processing Record 26 of Set 4 | potsdam
# Processing Record 27 of Set 4 | tucumcari
# Processing Record 28 of Set 4 | suzdal
# Processing Record 29 of Set 4 | fairbanks
# Processing Record 30 of Set 4 | chuy
# Processing Record 31 of Set 4 | koumac
# Processing Record 32 of Set 4 | orocue
# Processing Record 33 of Set 4 | blagoyevo
# Processing Record 34 of Set 4 | road town
# Processing Record 35 of Set 4 | fortuna
# Processing Record 36 of Set 4 | odweyne
# Processing Record 37 of Set 4 | juntas
# Processing Record 38 of Set 4 | vestmannaeyjar
# Processing Record 39 of Set 4 | lolua
# City not found. Skipping...
# Processing Record 40 of Set 4 | sijunjung
# Processing Record 41 of Set 4 | beloha
# Processing Record 42 of Set 4 | bethel
# Processing Record 43 of Set 4 | pekan
# Processing Record 44 of Set 4 | barranca
# Processing Record 45 of Set 4 | mount gambier
# Processing Record 46 of Set 4 | cidreira
# Processing Record 47 of Set 4 | the valley
# Processing Record 48 of Set 4 | provideniya
# Processing Record 49 of Set 4 | port hardy
# Processing Record 50 of Set 4 | muzhi
# Processing Record 1 of Set 5 | saint-philippe
# Processing Record 2 of Set 5 | luderitz
# Processing Record 3 of Set 5 | lagunas
# Processing Record 4 of Set 5 | amahai
# Processing Record 5 of Set 5 | kawana waters
# City not found. Skipping...
# Processing Record 6 of Set 5 | mitsamiouli
# Processing Record 7 of Set 5 | saint anthony
# Processing Record 8 of Set 5 | qandala
# Processing Record 9 of Set 5 | karaul
# City not found. Skipping...
# Processing Record 10 of Set 5 | rioja
# Processing Record 11 of Set 5 | wasilla
# Processing Record 12 of Set 5 | sandpoint
# Processing Record 13 of Set 5 | ningan
# City not found. Skipping...
# Processing Record 14 of Set 5 | arcachon
# Processing Record 15 of Set 5 | san patricio
# Processing Record 16 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 17 of Set 5 | rawson
# Processing Record 18 of Set 5 | tabiauea
# City not found. Skipping...
# Processing Record 19 of Set 5 | portland
# Processing Record 20 of Set 5 | coihueco
# Processing Record 21 of Set 5 | rocha
# Processing Record 22 of Set 5 | shimoda
# Processing Record 23 of Set 5 | folkestone
# Processing Record 24 of Set 5 | louisbourg
# City not found. Skipping...
# Processing Record 25 of Set 5 | meulaboh
# Processing Record 26 of Set 5 | pemba
# Processing Record 27 of Set 5 | paramonga
# Processing Record 28 of Set 5 | puerto carreno
# Processing Record 29 of Set 5 | mount isa
# Processing Record 30 of Set 5 | faanui
# Processing Record 31 of Set 5 | teguldet
# Processing Record 32 of Set 5 | pacific grove
# Processing Record 33 of Set 5 | faya
# Processing Record 34 of Set 5 | stavern
# Processing Record 35 of Set 5 | kudahuvadhoo
# Processing Record 36 of Set 5 | karratha
# Processing Record 37 of Set 5 | olga
# Processing Record 38 of Set 5 | mullaitivu
# City not found. Skipping...
# Processing Record 39 of Set 5 | grand-lahou
# Processing Record 40 of Set 5 | sault sainte marie
# Processing Record 41 of Set 5 | kollam
# Processing Record 42 of Set 5 | swan river
# Processing Record 43 of Set 5 | westpunt
# City not found. Skipping...
# Processing Record 44 of Set 5 | vardo
# Processing Record 45 of Set 5 | whitehorse
# Processing Record 46 of Set 5 | salumbar
# Processing Record 47 of Set 5 | acajutla
# Processing Record 48 of Set 5 | pisco
# Processing Record 49 of Set 5 | port blair
# Processing Record 50 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 1 of Set 6 | bolungarvik
# City not found. Skipping...
# Processing Record 2 of Set 6 | mayo
# Processing Record 3 of Set 6 | wulanhaote
# City not found. Skipping...
# Processing Record 4 of Set 6 | almaznyy
# Processing Record 5 of Set 6 | karauzyak
# City not found. Skipping...
# Processing Record 6 of Set 6 | turka
# Processing Record 7 of Set 6 | kampot
# Processing Record 8 of Set 6 | bratsk
# Processing Record 9 of Set 6 | tars
# Processing Record 10 of Set 6 | redding
# Processing Record 11 of Set 6 | souillac
# Processing Record 12 of Set 6 | marawi
# Processing Record 13 of Set 6 | neryungri
# Processing Record 14 of Set 6 | hamirpur
# Processing Record 15 of Set 6 | itarema
# Processing Record 16 of Set 6 | najran
# Processing Record 17 of Set 6 | kirensk
# Processing Record 18 of Set 6 | ruidoso
# Processing Record 19 of Set 6 | zeya
# Processing Record 20 of Set 6 | foumbot
# Processing Record 21 of Set 6 | dunedin
# Processing Record 22 of Set 6 | henties bay
# Processing Record 23 of Set 6 | phan rang
# City not found. Skipping...
# Processing Record 24 of Set 6 | champerico
# Processing Record 25 of Set 6 | malgrat de mar
# Processing Record 26 of Set 6 | antigonish
# Processing Record 27 of Set 6 | buchanan
# Processing Record 28 of Set 6 | ossora
# Processing Record 29 of Set 6 | mangan
# Processing Record 30 of Set 6 | abay
# Processing Record 31 of Set 6 | hare bay
# Processing Record 32 of Set 6 | waingapu
# Processing Record 33 of Set 6 | ilulissat
# Processing Record 34 of Set 6 | kailua
# Processing Record 35 of Set 6 | vila franca do campo
# Processing Record 36 of Set 6 | bonavista
# Processing Record 37 of Set 6 | yarada
# Processing Record 38 of Set 6 | ustye
# Processing Record 39 of Set 6 | vostok
# Processing Record 40 of Set 6 | mitu
# Processing Record 41 of Set 6 | santiago de chuco
# Processing Record 42 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 43 of Set 6 | timizart
# Processing Record 44 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 45 of Set 6 | uinskoye
# Processing Record 46 of Set 6 | wenatchee
# Processing Record 47 of Set 6 | kavieng
# Processing Record 48 of Set 6 | puebloviejo
# Processing Record 49 of Set 6 | vera cruz
# Processing Record 50 of Set 6 | pitanga
# Processing Record 1 of Set 7 | veraval
# Processing Record 2 of Set 7 | ilongero
# Processing Record 3 of Set 7 | nabire
# Processing Record 4 of Set 7 | bundaberg
# Processing Record 5 of Set 7 | billings
# Processing Record 6 of Set 7 | methven
# Processing Record 7 of Set 7 | galveston
# Processing Record 8 of Set 7 | katobu
# Processing Record 9 of Set 7 | nyazepetrovsk
# Processing Record 10 of Set 7 | znamenskoye
# Processing Record 11 of Set 7 | salinas
# Processing Record 12 of Set 7 | belaya gora
# Processing Record 13 of Set 7 | laguna
# Processing Record 14 of Set 7 | latung
# Processing Record 15 of Set 7 | malmyzh
# Processing Record 16 of Set 7 | swedru
# Processing Record 17 of Set 7 | taoudenni
# Processing Record 18 of Set 7 | requena
# Processing Record 19 of Set 7 | dryden
# Processing Record 20 of Set 7 | sur
# Processing Record 21 of Set 7 | guerrero negro
# Processing Record 22 of Set 7 | taltal
# Processing Record 23 of Set 7 | esperance
# Processing Record 24 of Set 7 | edson
# Processing Record 25 of Set 7 | praia da vitoria
# Processing Record 26 of Set 7 | mahebourg
# Processing Record 27 of Set 7 | alofi
# Processing Record 28 of Set 7 | komsomolskiy
# Processing Record 29 of Set 7 | benguela
# Processing Record 30 of Set 7 | puerto el triunfo
# Processing Record 31 of Set 7 | sarakhs
# Processing Record 32 of Set 7 | muros
# Processing Record 33 of Set 7 | vigeland
# Processing Record 34 of Set 7 | skalistyy
# City not found. Skipping...
# Processing Record 35 of Set 7 | fomboni
# Processing Record 36 of Set 7 | cordoba
# Processing Record 37 of Set 7 | ixtapa
# Processing Record 38 of Set 7 | zhezkazgan
# Processing Record 39 of Set 7 | yambio
# Processing Record 40 of Set 7 | thabazimbi
# Processing Record 41 of Set 7 | mweka
# Processing Record 42 of Set 7 | berdigestyakh
# Processing Record 43 of Set 7 | kismayo
# Processing Record 44 of Set 7 | praia
# Processing Record 45 of Set 7 | tashtyp
# Processing Record 46 of Set 7 | shaoxing
# Processing Record 47 of Set 7 | paracatu
# Processing Record 48 of Set 7 | el balyana
# City not found. Skipping...
# Processing Record 49 of Set 7 | kamenskoye
# City not found. Skipping...
# Processing Record 50 of Set 7 | bayan
# Processing Record 1 of Set 8 | longyearbyen
# Processing Record 2 of Set 8 | nome
# Processing Record 3 of Set 8 | sisimiut
# Processing Record 4 of Set 8 | yelizovo
# Processing Record 5 of Set 8 | villa maria
# Processing Record 6 of Set 8 | lavrentiya
# Processing Record 7 of Set 8 | dong hoi
# Processing Record 8 of Set 8 | skibbereen
# Processing Record 9 of Set 8 | puerto ayacucho
# Processing Record 10 of Set 8 | cardston
# Processing Record 11 of Set 8 | tonekabon
# Processing Record 12 of Set 8 | shiraz
# Processing Record 13 of Set 8 | hilo
# Processing Record 14 of Set 8 | khatanga
# Processing Record 15 of Set 8 | bathsheba
# Processing Record 16 of Set 8 | bati
# Processing Record 17 of Set 8 | kargil
# Processing Record 18 of Set 8 | sentyabrskiy
# City not found. Skipping...
# Processing Record 19 of Set 8 | cherskiy
# Processing Record 20 of Set 8 | oistins
# Processing Record 21 of Set 8 | dutlwe
# Processing Record 22 of Set 8 | nezhinka
# Processing Record 23 of Set 8 | xiongyue
# Processing Record 24 of Set 8 | magadan
# Processing Record 25 of Set 8 | umm lajj
# Processing Record 26 of Set 8 | neftekumsk
# Processing Record 27 of Set 8 | ushtobe
# Processing Record 28 of Set 8 | usinsk
# Processing Record 29 of Set 8 | alugan
# Processing Record 30 of Set 8 | te anau
# Processing Record 31 of Set 8 | san quintin
# Processing Record 32 of Set 8 | gamba
# Processing Record 33 of Set 8 | kattivakkam
# Processing Record 34 of Set 8 | andenes
# Processing Record 35 of Set 8 | ishigaki
# Processing Record 36 of Set 8 | gravdal
# Processing Record 37 of Set 8 | huambo
# Processing Record 38 of Set 8 | ahome
# Processing Record 39 of Set 8 | pringsewu
# Processing Record 40 of Set 8 | kenai
# Processing Record 41 of Set 8 | sechura
# Processing Record 42 of Set 8 | altar
# Processing Record 43 of Set 8 | takoradi
# Processing Record 44 of Set 8 | asheville
# Processing Record 45 of Set 8 | taseyevo
# Processing Record 46 of Set 8 | isangel
# Processing Record 47 of Set 8 | camacha
# Processing Record 48 of Set 8 | gbarnga
# Processing Record 49 of Set 8 | troitskoye
# Processing Record 50 of Set 8 | haines junction
# Processing Record 1 of Set 9 | inirida
# Processing Record 2 of Set 9 | oktyabrskiy
# Processing Record 3 of Set 9 | diveyevo
# Processing Record 4 of Set 9 | canto do buriti
# Processing Record 5 of Set 9 | saint-pierre
# Processing Record 6 of Set 9 | warrington
# Processing Record 7 of Set 9 | san policarpo
# Processing Record 8 of Set 9 | lasa
# Processing Record 9 of Set 9 | sampit
# Processing Record 10 of Set 9 | saint-augustin
# Processing Record 11 of Set 9 | faridabad
# Processing Record 12 of Set 9 | raton
# Processing Record 13 of Set 9 | mandalgovi
# Processing Record 14 of Set 9 | quatre cocos
# Processing Record 15 of Set 9 | maceio
# Processing Record 16 of Set 9 | palos verdes estates
# Processing Record 17 of Set 9 | ahuimanu
# Processing Record 18 of Set 9 | havelock
# Processing Record 19 of Set 9 | barcelos
# Processing Record 20 of Set 9 | gallup
# Processing Record 21 of Set 9 | knysna
# Processing Record 22 of Set 9 | san antonio
# Processing Record 23 of Set 9 | huaihua
# Processing Record 24 of Set 9 | soure
# Processing Record 25 of Set 9 | khonuu
# City not found. Skipping...
# Processing Record 26 of Set 9 | bereda
# Processing Record 27 of Set 9 | aguas de lindoia
# Processing Record 28 of Set 9 | huarmey
# Processing Record 29 of Set 9 | xuchang
# Processing Record 30 of Set 9 | villamontes
# Processing Record 31 of Set 9 | buzuluk
# Processing Record 32 of Set 9 | mezhdurechensk
# Processing Record 33 of Set 9 | lazo
# Processing Record 34 of Set 9 | hualmay
# Processing Record 35 of Set 9 | nelson bay
# Processing Record 36 of Set 9 | fort nelson
# Processing Record 37 of Set 9 | carbondale
# Processing Record 38 of Set 9 | sabang
# Processing Record 39 of Set 9 | teknaf
# Processing Record 40 of Set 9 | santiago de cao
# Processing Record 41 of Set 9 | pierre
# Processing Record 42 of Set 9 | leningradskiy
# Processing Record 43 of Set 9 | emerald
# Processing Record 44 of Set 9 | riviere-au-renard
# Processing Record 45 of Set 9 | havre-saint-pierre
# Processing Record 46 of Set 9 | sassandra
# Processing Record 47 of Set 9 | bengkulu
# Processing Record 48 of Set 9 | pinotepa nacional
# Processing Record 49 of Set 9 | lakes entrance
# Processing Record 50 of Set 9 | hamilton
# Processing Record 1 of Set 10 | vaitupu
# City not found. Skipping...
# Processing Record 2 of Set 10 | jiazi
# Processing Record 3 of Set 10 | vila do maio
# Processing Record 4 of Set 10 | panalingaan
# Processing Record 5 of Set 10 | puerto madero
# Processing Record 6 of Set 10 | sambava
# Processing Record 7 of Set 10 | iskateley
# Processing Record 8 of Set 10 | oranjemund
# Processing Record 9 of Set 10 | mendi
# Processing Record 10 of Set 10 | marsaxlokk
# Processing Record 11 of Set 10 | goderich
# Processing Record 12 of Set 10 | airai
# Processing Record 13 of Set 10 | sitka
# Processing Record 14 of Set 10 | makakilo city
# Processing Record 15 of Set 10 | kaeo
# Processing Record 16 of Set 10 | touros
# Processing Record 17 of Set 10 | olhao
# Processing Record 18 of Set 10 | urdoma
# Processing Record 19 of Set 10 | paso de los toros
# Processing Record 20 of Set 10 | luena
# Processing Record 21 of Set 10 | nizhniy tagil-39
# City not found. Skipping...
# Processing Record 22 of Set 10 | indramayu
# Processing Record 23 of Set 10 | kununurra
# Processing Record 24 of Set 10 | bellinzona
# Processing Record 25 of Set 10 | hambantota
# Processing Record 26 of Set 10 | caravelas
# Processing Record 27 of Set 10 | imeni zhelyabova
# Processing Record 28 of Set 10 | nouadhibou
# Processing Record 29 of Set 10 | geraldton
# Processing Record 30 of Set 10 | paita
# Processing Record 31 of Set 10 | ust-ilimsk
# Processing Record 32 of Set 10 | yerbogachen
# Processing Record 33 of Set 10 | satao
# Processing Record 34 of Set 10 | am timan
# Processing Record 35 of Set 10 | pangnirtung
# Processing Record 36 of Set 10 | bergerac
# Processing Record 37 of Set 10 | haflong
# Processing Record 38 of Set 10 | mafeteng
# Processing Record 39 of Set 10 | marcona
# City not found. Skipping...
# Processing Record 40 of Set 10 | hofn
# Processing Record 41 of Set 10 | takhatgarh
# Processing Record 42 of Set 10 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 43 of Set 10 | kuching
# Processing Record 44 of Set 10 | razole
# Processing Record 45 of Set 10 | yar-sale
# Processing Record 46 of Set 10 | springbok
# Processing Record 47 of Set 10 | liuli
# Processing Record 48 of Set 10 | arvika
# Processing Record 49 of Set 10 | savannah bight
# Processing Record 50 of Set 10 | yorkton
# Processing Record 1 of Set 11 | bambanglipuro
# Processing Record 2 of Set 11 | malwan
# City not found. Skipping...
# Processing Record 3 of Set 11 | bunol
# Processing Record 4 of Set 11 | minyar
# Processing Record 5 of Set 11 | bayburt
# Processing Record 6 of Set 11 | belawan
# Processing Record 7 of Set 11 | dong xoai
# Processing Record 8 of Set 11 | saintes
# Processing Record 9 of Set 11 | new cumnock
# Processing Record 10 of Set 11 | tagusao
# Processing Record 11 of Set 11 | maningrida
# Processing Record 12 of Set 11 | saint augustine
# Processing Record 13 of Set 11 | xuddur
# Processing Record 14 of Set 11 | bogo
# Processing Record 15 of Set 11 | arrifes
# Processing Record 16 of Set 11 | neuquen
# Processing Record 17 of Set 11 | izumo
# Processing Record 18 of Set 11 | ilhabela
# Processing Record 19 of Set 11 | amapa
# Processing Record 20 of Set 11 | agapovka
# Processing Record 21 of Set 11 | moose factory
# Processing Record 22 of Set 11 | berlevag
# Processing Record 23 of Set 11 | saint-honore
# Processing Record 24 of Set 11 | surt
# Processing Record 25 of Set 11 | el paso
# Processing Record 26 of Set 11 | rafai
# Processing Record 27 of Set 11 | richards bay
# Processing Record 28 of Set 11 | orange cove
# Processing Record 29 of Set 11 | anchorage
# Processing Record 30 of Set 11 | imperia
# Processing Record 31 of Set 11 | svobodnyy
# Processing Record 32 of Set 11 | san pedro de macoris
# Processing Record 33 of Set 11 | hasaki
# Processing Record 34 of Set 11 | shakhtinsk
# Processing Record 35 of Set 11 | turayf
# Processing Record 36 of Set 11 | dezful
# Processing Record 37 of Set 11 | salalah
# Processing Record 38 of Set 11 | kindia
# Processing Record 39 of Set 11 | falam
# Processing Record 40 of Set 11 | hunza
# City not found. Skipping...
# Processing Record 41 of Set 11 | punta cardon
# Processing Record 42 of Set 11 | codrington
# Processing Record 43 of Set 11 | manaus
# Processing Record 44 of Set 11 | vila
# Processing Record 45 of Set 11 | pimentel
# Processing Record 46 of Set 11 | bethanien
# Processing Record 47 of Set 11 | iralaya
# Processing Record 48 of Set 11 | kabare
# Processing Record 49 of Set 11 | klaksvik
# Processing Record 50 of Set 11 | san carlos de bariloche
# Processing Record 1 of Set 12 | lorengau
# Processing Record 2 of Set 12 | kangayam
# Processing Record 3 of Set 12 | cockburn town
# Processing Record 4 of Set 12 | karata
# Processing Record 5 of Set 12 | huazhou
# Processing Record 6 of Set 12 | lerici
# Processing Record 7 of Set 12 | petropavlovka
# Processing Record 8 of Set 12 | caceres
# Processing Record 9 of Set 12 | akot
# Processing Record 10 of Set 12 | longkou
# Processing Record 11 of Set 12 | itoman
# Processing Record 12 of Set 12 | isla mujeres
# Processing Record 13 of Set 12 | yumen
# Processing Record 14 of Set 12 | wewak
# Processing Record 15 of Set 12 | college
# Processing Record 16 of Set 12 | marsa matruh
# Processing Record 17 of Set 12 | linjiang
# Processing Record 18 of Set 12 | soe
# Processing Record 19 of Set 12 | bayji
# Processing Record 20 of Set 12 | imbituba
# Processing Record 21 of Set 12 | khani
# Processing Record 22 of Set 12 | kapit
# Processing Record 23 of Set 12 | yabrud
# Processing Record 24 of Set 12 | iracoubo
# Processing Record 25 of Set 12 | omsukchan
# Processing Record 26 of Set 12 | aquiraz
# Processing Record 27 of Set 12 | woodward
# Processing Record 28 of Set 12 | san cristobal
# Processing Record 29 of Set 12 | turukhansk
# Processing Record 30 of Set 12 | san andres
# Processing Record 31 of Set 12 | ntungamo
# Processing Record 32 of Set 12 | camapua
# Processing Record 33 of Set 12 | rafraf
# Processing Record 34 of Set 12 | talnakh
# Processing Record 35 of Set 12 | tabuk
# Processing Record 36 of Set 12 | aberdeen
# Processing Record 37 of Set 12 | grindavik
# Processing Record 38 of Set 12 | snasa
# Processing Record 39 of Set 12 | merauke
# Processing Record 40 of Set 12 | adrar
# Processing Record 41 of Set 12 | linares
# Processing Record 42 of Set 12 | san angelo
# Processing Record 43 of Set 12 | nova olimpia
# Processing Record 44 of Set 12 | ziarat
# Processing Record 45 of Set 12 | juba
# Processing Record 46 of Set 12 | ruatoria
# City not found. Skipping...
# Processing Record 47 of Set 12 | keti bandar
# Processing Record 48 of Set 12 | ovsyanka
# Processing Record 49 of Set 12 | cururupu
# Processing Record 50 of Set 12 | osypenko
# Processing Record 1 of Set 13 | mahon
# Processing Record 2 of Set 13 | srednekolymsk
# Processing Record 3 of Set 13 | diego de almagro
# Processing Record 4 of Set 13 | sandwick
# Processing Record 5 of Set 13 | hobyo
# Processing Record 6 of Set 13 | kathu
# Processing Record 7 of Set 13 | bellevue
# Processing Record 8 of Set 13 | chhabra
# Processing Record 9 of Set 13 | tadine
# Processing Record 10 of Set 13 | buraydah
# Processing Record 11 of Set 13 | nao-me-toque
# City not found. Skipping...
# Processing Record 12 of Set 13 | yaan
# Processing Record 13 of Set 13 | ramon castilla
# Processing Record 14 of Set 13 | bhairab bazar
# Processing Record 15 of Set 13 | oreanda
# City not found. Skipping...
# Processing Record 16 of Set 13 | lusambo
# Processing Record 17 of Set 13 | sibu
# Processing Record 18 of Set 13 | hihifo
# City not found. Skipping...
# Processing Record 19 of Set 13 | roald
# Processing Record 20 of Set 13 | belmonte
# Processing Record 21 of Set 13 | avera
# Processing Record 22 of Set 13 | heihe
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 574

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Ushuaia      AR -54.8000  -68.3000     56.82        50           0
# 1   Tuktoyaktuk      CA  69.4541 -133.0374     28.40        93         100
# 2      Hermanus      ZA -34.4187   19.2345     63.81        95          82
# 3      Tessalit      ML  20.1986    1.0114     90.05        14           6
# 4     Kavaratti      IN  10.5669   72.6420     80.83        80          97
# 5      Olafsvik      IS  64.8945  -23.7142     42.08        70          54
# 6    Chokurdakh      RU  70.6333  147.9167     14.59        96          99
# 7     Busselton      AU -33.6500  115.3333     49.69        89           0
# 8     Saskylakh      RU  71.9167  114.0833      3.02        99          96
# 9  Ponta Do Sol      PT  32.6667  -17.1000     76.01        76          11
#
#    Wind Speed Current Description
# 0       23.02           clear sky
# 1        5.75     overcast clouds
# 2        2.39       broken clouds
# 3        9.26           clear sky
# 4       15.73     overcast clouds
# 5        8.03       broken clouds
# 6        9.04     overcast clouds
# 7        6.31           clear sky
# 8        3.62     overcast clouds
# 9        9.22          few clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Ushuaia      AR -54.8000  -68.3000     56.82        50           0
# 1    Tuktoyaktuk      CA  69.4541 -133.0374     28.40        93         100
# 2       Hermanus      ZA -34.4187   19.2345     63.81        95          82
# 3       Tessalit      ML  20.1986    1.0114     90.05        14           6
# 4      Kavaratti      IN  10.5669   72.6420     80.83        80          97
# ..           ...     ...      ...       ...       ...       ...         ...
# 569         Sibu      MY   2.3000  111.8167     77.31        94          40
# 570        Roald      NO  62.5833    6.1333     51.75        87          75
# 571     Belmonte      BR -15.8631  -38.8828     79.75        66          30
# 572        Avera      US  33.1940  -82.5271     80.55        41          99
# 573        Heihe      CN  50.2441  127.4902     30.78        57           1
#
#      Wind Speed Current Description
# 0         23.02           clear sky
# 1          5.75     overcast clouds
# 2          2.39       broken clouds
# 3          9.26           clear sky
# 4         15.73     overcast clouds
# ..          ...                 ...
# 569        2.30          light rain
# 570       10.36       broken clouds
# 571       10.04    scattered clouds
# 572       14.85     overcast clouds
# 573       10.76           clear sky
#
# [574 rows x 9 columns]

# %%
# Display the data types of each column by using the dtypes Pandas function
type(city_data_df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "../Weather_Database/WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
