# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
# Copy from WeatherPy

lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 643

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
#dont forget to delete url because it has the api address
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        # YOUR CODE HERE       
            
        # Append the city information into the city_data list
        # YOUR CODE HERE
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | vaini
# Processing Record 2 of Set 1 | northam
# Processing Record 3 of Set 1 | isangel
# Processing Record 4 of Set 1 | nador
# Processing Record 5 of Set 1 | rikitea
# Processing Record 6 of Set 1 | georgetown
# Processing Record 7 of Set 1 | cobija
# Processing Record 8 of Set 1 | port elizabeth
# Processing Record 9 of Set 1 | gotsu
# Processing Record 10 of Set 1 | shelburne
# Processing Record 11 of Set 1 | chokurdakh
# Processing Record 12 of Set 1 | tokur
# Processing Record 13 of Set 1 | svetlaya
# Processing Record 14 of Set 1 | sangar
# Processing Record 15 of Set 1 | fevralsk
# Processing Record 16 of Set 1 | cape town
# Processing Record 17 of Set 1 | busselton
# Processing Record 18 of Set 1 | taolanaro
# Processing Record 19 of Set 1 | haines junction
# Processing Record 20 of Set 1 | honolulu
# Processing Record 21 of Set 1 | campobello di mazara
# Processing Record 22 of Set 1 | mataura
# Processing Record 23 of Set 1 | saint george
# Processing Record 24 of Set 1 | kaitangata
# Processing Record 25 of Set 1 | luderitz
# Processing Record 26 of Set 1 | ushuaia
# Processing Record 27 of Set 1 | port hardy
# Processing Record 28 of Set 1 | kidal
# Processing Record 29 of Set 1 | santa cruz
# Processing Record 30 of Set 1 | bluff
# Processing Record 31 of Set 1 | ruatoria
# Processing Record 32 of Set 1 | jamestown
# Processing Record 33 of Set 1 | nikolskoye
# Processing Record 34 of Set 1 | punta arenas
# Processing Record 35 of Set 1 | roald
# Processing Record 36 of Set 1 | tiksi
# Processing Record 37 of Set 1 | mastung
# Processing Record 38 of Set 1 | guerrero negro
# Processing Record 39 of Set 1 | warri
# Processing Record 40 of Set 1 | barra patuca
# Processing Record 41 of Set 1 | fort myers beach
# Processing Record 42 of Set 1 | yellowknife
# Processing Record 43 of Set 1 | saskylakh
# Processing Record 44 of Set 1 | puerto escondido
# Processing Record 45 of Set 1 | kailua
# Processing Record 46 of Set 1 | sao joao da barra
# Processing Record 47 of Set 1 | bethel
# Processing Record 48 of Set 1 | paciran
# Processing Record 49 of Set 1 | samusu
# Processing Record 50 of Set 1 | puerto ayora
# Processing Record 1 of Set 2 | faanui
# Processing Record 2 of Set 2 | nagorsk
# Processing Record 3 of Set 2 | belushya guba
# Processing Record 4 of Set 2 | gazojak
# Processing Record 5 of Set 2 | istok
# Processing Record 6 of Set 2 | carnarvon
# Processing Record 7 of Set 2 | manadhoo
# Processing Record 8 of Set 2 | pandelys
# Processing Record 9 of Set 2 | lebu
# Processing Record 10 of Set 2 | kapaa
# Processing Record 11 of Set 2 | hithadhoo
# Processing Record 12 of Set 2 | esperance
# Processing Record 13 of Set 2 | hilo
# Processing Record 14 of Set 2 | richards bay
# Processing Record 15 of Set 2 | maunabo
# Processing Record 16 of Set 2 | barrow
# Processing Record 17 of Set 2 | barentsburg
# Processing Record 18 of Set 2 | hermanus
# Processing Record 19 of Set 2 | bambous virieux
# Processing Record 20 of Set 2 | hihifo
# Processing Record 21 of Set 2 | la orilla
# Processing Record 22 of Set 2 | palabuhanratu
# Processing Record 23 of Set 2 | port blair
# Processing Record 24 of Set 2 | nishihara
# Processing Record 25 of Set 2 | ereymentau
# Processing Record 26 of Set 2 | vila franca do campo
# Processing Record 27 of Set 2 | ussuriysk
# Processing Record 28 of Set 2 | illoqqortoormiut
# Processing Record 29 of Set 2 | ahuimanu
# Processing Record 30 of Set 2 | nome
# Processing Record 31 of Set 2 | hobart
# Processing Record 32 of Set 2 | norton shores
# Processing Record 33 of Set 2 | tuktoyaktuk
# Processing Record 34 of Set 2 | mehamn
# Processing Record 35 of Set 2 | porosozero
# Processing Record 36 of Set 2 | tilichiki
# Processing Record 37 of Set 2 | albany
# Processing Record 38 of Set 2 | maragogi
# Processing Record 39 of Set 2 | ponta do sol
# Processing Record 40 of Set 2 | meyungs
# Processing Record 41 of Set 2 | margate
# Processing Record 42 of Set 2 | broadstairs
# Processing Record 43 of Set 2 | upernavik
# Processing Record 44 of Set 2 | tsihombe
# Processing Record 45 of Set 2 | birecik
# Processing Record 46 of Set 2 | lolua
# Processing Record 47 of Set 2 | ust-barguzin
# Processing Record 48 of Set 2 | nuuk
# Processing Record 49 of Set 2 | humaita
# Processing Record 50 of Set 2 | reims
# Processing Record 1 of Set 3 | marzuq
# Processing Record 2 of Set 3 | samalaeulu
# Processing Record 3 of Set 3 | galiwinku
# Processing Record 4 of Set 3 | campbell river
# Processing Record 5 of Set 3 | san patricio
# Processing Record 6 of Set 3 | maykain
# Processing Record 7 of Set 3 | lagoa
# Processing Record 8 of Set 3 | ilka
# Processing Record 9 of Set 3 | vilhena
# Processing Record 10 of Set 3 | poronaysk
# Processing Record 11 of Set 3 | vardo
# Processing Record 12 of Set 3 | koungou
# Processing Record 13 of Set 3 | louisbourg
# Processing Record 14 of Set 3 | muyezerskiy
# Processing Record 15 of Set 3 | castro
# Processing Record 16 of Set 3 | codrington
# Processing Record 17 of Set 3 | kapoeta
# Processing Record 18 of Set 3 | butaritari
# Processing Record 19 of Set 3 | bredasdorp
# Processing Record 20 of Set 3 | vaitupu
# Processing Record 21 of Set 3 | clyde river
# Processing Record 22 of Set 3 | okhotsk
# Processing Record 23 of Set 3 | san felipe
# Processing Record 24 of Set 3 | airai
# Processing Record 25 of Set 3 | hirara
# Processing Record 26 of Set 3 | ilulissat
# Processing Record 27 of Set 3 | dzemul
# Processing Record 28 of Set 3 | nadym
# Processing Record 29 of Set 3 | quatre cocos
# Processing Record 30 of Set 3 | itoman
# Processing Record 31 of Set 3 | port augusta
# Processing Record 32 of Set 3 | atuona
# Processing Record 33 of Set 3 | naze
# Processing Record 34 of Set 3 | gazanjyk
# Processing Record 35 of Set 3 | verkhnevilyuysk
# Processing Record 36 of Set 3 | bathsheba
# Processing Record 37 of Set 3 | kirakira
# Processing Record 38 of Set 3 | norman wells
# Processing Record 39 of Set 3 | saint-philippe
# Processing Record 40 of Set 3 | broome
# Processing Record 41 of Set 3 | punta de bombon
# Processing Record 42 of Set 3 | daura
# Processing Record 43 of Set 3 | port alfred
# Processing Record 44 of Set 3 | nantucket
# Processing Record 45 of Set 3 | tessalit
# Processing Record 46 of Set 3 | zhanaozen
# Processing Record 47 of Set 3 | tocopilla
# Processing Record 48 of Set 3 | wanaka
# Processing Record 49 of Set 3 | ballina
# Processing Record 50 of Set 3 | biak
# Processing Record 1 of Set 4 | helena
# Processing Record 2 of Set 4 | samarai
# Processing Record 3 of Set 4 | san marcos
# Processing Record 4 of Set 4 | koshurnikovo
# Processing Record 5 of Set 4 | yashkul
# Processing Record 6 of Set 4 | pingdu
# Processing Record 7 of Set 4 | khatanga
# Processing Record 8 of Set 4 | panguna
# Processing Record 9 of Set 4 | alofi
# Processing Record 10 of Set 4 | praia da vitoria
# Processing Record 11 of Set 4 | sao filipe
# Processing Record 12 of Set 4 | arraial do cabo
# Processing Record 13 of Set 4 | haimen
# Processing Record 14 of Set 4 | hobyo
# Processing Record 15 of Set 4 | henties bay
# Processing Record 16 of Set 4 | nenjiang
# Processing Record 17 of Set 4 | chuy
# Processing Record 18 of Set 4 | bay-khaak
# Processing Record 19 of Set 4 | sao benedito do rio preto
# Processing Record 20 of Set 4 | biltine
# Processing Record 21 of Set 4 | fortuna
# Processing Record 22 of Set 4 | serrinha
# Processing Record 23 of Set 4 | pennagaram
# Processing Record 24 of Set 4 | nouadhibou
# Processing Record 25 of Set 4 | pacific grove
# Processing Record 26 of Set 4 | lae
# Processing Record 27 of Set 4 | formoso do araguaia
# Processing Record 28 of Set 4 | san luis
# Processing Record 29 of Set 4 | dingle
# Processing Record 30 of Set 4 | taburi
# Processing Record 31 of Set 4 | muros
# Processing Record 32 of Set 4 | leningradskiy
# Processing Record 33 of Set 4 | vao
# Processing Record 34 of Set 4 | touros
# Processing Record 35 of Set 4 | nemuro
# Processing Record 36 of Set 4 | araouane
# Processing Record 37 of Set 4 | natal
# Processing Record 38 of Set 4 | hemsedal
# Processing Record 39 of Set 4 | hornepayne
# Processing Record 40 of Set 4 | north adams
# Processing Record 41 of Set 4 | port hedland
# Processing Record 42 of Set 4 | nanortalik
# Processing Record 43 of Set 4 | hirado
# Processing Record 44 of Set 4 | asfi
# Processing Record 45 of Set 4 | dikson
# Processing Record 46 of Set 4 | lata
# Processing Record 47 of Set 4 | santa maria
# Processing Record 48 of Set 4 | comal
# Processing Record 49 of Set 4 | torbay
# Processing Record 50 of Set 4 | attawapiskat
# Processing Record 1 of Set 5 | shwebo
# Processing Record 2 of Set 5 | noumea
# Processing Record 3 of Set 5 | tulum
# Processing Record 4 of Set 5 | maarianhamina
# Processing Record 5 of Set 5 | new norfolk
# Processing Record 6 of Set 5 | azare
# Processing Record 7 of Set 5 | hay river
# Processing Record 8 of Set 5 | avera
# Processing Record 9 of Set 5 | kargasok
# Processing Record 10 of Set 5 | amderma
# Processing Record 11 of Set 5 | viedma
# Processing Record 12 of Set 5 | qeshm
# Processing Record 13 of Set 5 | lillooet
# Processing Record 14 of Set 5 | nizhneyansk
# Processing Record 15 of Set 5 | stillwater
# Processing Record 16 of Set 5 | arlit
# Processing Record 17 of Set 5 | kundiawa
# Processing Record 18 of Set 5 | san anselmo
# Processing Record 19 of Set 5 | hami
# Processing Record 20 of Set 5 | eskasem
# Processing Record 21 of Set 5 | dodoma
# Processing Record 22 of Set 5 | hays
# Processing Record 23 of Set 5 | kahului
# Processing Record 24 of Set 5 | cockburn town
# Processing Record 25 of Set 5 | dawei
# Processing Record 26 of Set 5 | benguela
# Processing Record 27 of Set 5 | verkhnyaya pyshma
# Processing Record 28 of Set 5 | te anau
# Processing Record 29 of Set 5 | mrirt
# Processing Record 30 of Set 5 | valdosta
# Processing Record 31 of Set 5 | estevan
# Processing Record 32 of Set 5 | petropavlovsk-kamchatskiy
# Processing Record 33 of Set 5 | pirovskoye
# Processing Record 34 of Set 5 | marrakesh
# Processing Record 35 of Set 5 | kodiak
# Processing Record 36 of Set 5 | bururi
# Processing Record 37 of Set 5 | kamaishi
# Processing Record 38 of Set 5 | grindavik
# Processing Record 39 of Set 5 | los llanos de aridane
# Processing Record 40 of Set 5 | sorsk
# Processing Record 41 of Set 5 | bilma
# Processing Record 42 of Set 5 | kruisfontein
# Processing Record 43 of Set 5 | toppenish
# Processing Record 44 of Set 5 | aloleng
# Processing Record 45 of Set 5 | kuminskiy
# Processing Record 46 of Set 5 | srednekolymsk
# Processing Record 47 of Set 5 | gallup
# Processing Record 48 of Set 5 | lufilufi
# Processing Record 49 of Set 5 | novo aripuana
# Processing Record 50 of Set 5 | puerto asis
# Processing Record 1 of Set 6 | katangli
# Processing Record 2 of Set 6 | grand centre
# Processing Record 3 of Set 6 | bauchi
# Processing Record 4 of Set 6 | batemans bay
# Processing Record 5 of Set 6 | constitucion
# Processing Record 6 of Set 6 | san cristobal
# Processing Record 7 of Set 6 | east london
# Processing Record 8 of Set 6 | nelson bay
# Processing Record 9 of Set 6 | cabedelo
# Processing Record 10 of Set 6 | grand river south east
# Processing Record 11 of Set 6 | sassandra
# Processing Record 12 of Set 6 | belmonte
# Processing Record 13 of Set 6 | bandarbeyla
# Processing Record 14 of Set 6 | klaksvik
# Processing Record 15 of Set 6 | zaysan
# Processing Record 16 of Set 6 | iquitos
# Processing Record 17 of Set 6 | ambulu
# Processing Record 18 of Set 6 | yaan
# Processing Record 19 of Set 6 | tanda
# Processing Record 20 of Set 6 | newcastle
# Processing Record 21 of Set 6 | binabalian
# Processing Record 22 of Set 6 | katsuura
# Processing Record 23 of Set 6 | oranjemund
# Processing Record 24 of Set 6 | victoria
# Processing Record 25 of Set 6 | santiago de cao
# Processing Record 26 of Set 6 | mahibadhoo
# Processing Record 27 of Set 6 | raga
# Processing Record 28 of Set 6 | cherskiy
# Processing Record 29 of Set 6 | kaili
# Processing Record 30 of Set 6 | rudsar
# Processing Record 31 of Set 6 | nguiu
# Processing Record 32 of Set 6 | klyuchi
# Processing Record 33 of Set 6 | kadykchan
# Processing Record 34 of Set 6 | mitchell
# Processing Record 35 of Set 6 | half moon bay
# Processing Record 36 of Set 6 | nioro
# Processing Record 37 of Set 6 | kieta
# Processing Record 38 of Set 6 | campo do brito
# Processing Record 39 of Set 6 | lorengau
# Processing Record 40 of Set 6 | cidreira
# Processing Record 41 of Set 6 | salto
# Processing Record 42 of Set 6 | lodwar
# Processing Record 43 of Set 6 | wajima
# Processing Record 44 of Set 6 | mahebourg
# Processing Record 45 of Set 6 | port-gentil
# Processing Record 46 of Set 6 | saint-pierre
# Processing Record 47 of Set 6 | sistranda
# Processing Record 48 of Set 6 | cabo san lucas
# Processing Record 49 of Set 6 | olean
# Processing Record 50 of Set 6 | geraldton

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df

# %%
# Display the data types of each column by using the dtypes Pandas function
# YOUR CODE HERE

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "weather_data/cities.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
